# %% [markdown]
# <a href="https://colab.research.google.com/github/MxMathe/Dio-Treinamento/blob/main/Avaliacao_de_aprendizado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, confusion_matrix

# %% [markdown]
# *Gerar rótulos*

# %%
y_true = np.random.randint(0, 2, size=100)
y_pred = np.random.randint(0, 2, size=100)

# %% [markdown]
# *Gerar matriz de confusão*

# %%
cm = confusion_matrix(y_true, y_pred)

# %% [markdown]
# *Extrair valores*

# %%
TN, FP, FN, TP = cm.ravel()

# %% [markdown]
# *Cálculo*

# %%
acuracia = (TP + TN) / (TP + TN + FP + FN)
precisao = TP / (TP + FP) if (TP + FP) != 0 else 0
recall = TP / (TP + FN) if (TP + FN) != 0 else 0
especificidade = TN / (TN + FP) if (TN + FP) != 0 else 0
f1_score = 2 * (precisao * recall) / (precisao + recall) if (precisao + recall) != 0 else 0

# %% [markdown]
# *Matriz de confusão*

# %%
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Negativo", "Positivo"], yticklabels=["Negativo", "Positivo"])
plt.xlabel("Previsto")
plt.ylabel("Real")
plt.title("Matriz de Confusão")
plt.show()

# %% [markdown]
# *Resultados*

# %%
print(f"Acurácia: {acuracia:.2f}")
print(f"Precisão: {precisao:.2f}")
print(f"Sensibilidade (Recall): {recall:.2f}")
print(f"Especificidade: {especificidade:.2f}")
print(f"F1-Score: {f1_score:.2f}")
# Out:
# Acurácia: 0.44
# Precisão: 0.47
# Sensibilidade (Recall): 0.42
# Especificidade: 0.47
# F1-Score: 0.44

# %%
y_true = np.random.randint(0, 2, size=100)  # Valores reais (0 ou 1)
y_scores = np.random.rand(100)

# %% [markdown]
# *Calcular a curva de ROC*

# %%
fpr, tpr, _ = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# %% [markdown]
# *Plotar a curva de ROC*

# %%
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'Curva ROC (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Linha diagonal de referência
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taxa de Falsos Positivos (FPR)')
plt.ylabel('Taxa de Verdadeiros Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.grid()
plt.show()

# %%
print(f"Área sob a curva ROC (AUC): {roc_auc:.2f}")
# Out:
# Área sob a curva ROC (AUC): 0.53
